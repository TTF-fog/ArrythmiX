# %% [markdown]
# <!-- This should be added to the overrides/main.html and improved-->
# <div class="grid cards" markdown>
#
# - <svg xmlns="http://www.w3.org/2000/svg" height="50" width="50" viewBox="0 0 488 512"><!--!Font Awesome Free 6.6.0 by @fontawesome - https://fontawesome.com License - https://fontawesome.com/license/free Copyright 2024 Fonticons, Inc.--><path fill="#2094F3" d="M488 261.8C488 403.3 391.1 504 248 504 110.8 504 0 393.2 0 256S110.8 8 248 8c66.8 0 123 24.5 166.3 64.9l-67.5 64.9C258.5 52.6 94.3 116.6 94.3 256c0 86.5 69.1 156.6 153.7 156.6 98.2 0 135-70.4 140.8-106.9H248v-85.3h236.1c2.3 12.7 3.9 24.9 3.9 41.4z"/></svg>
# <a href="https://colab.research.google.com/github/AmbiqAI/heartkit/blob/main/docs/guides/train-arrhythmia-model.ipynb" class="md-content__button md-icon" style="color: #2094F3;">
#     View in Colab
# </a>
#
# - <svg xmlns="http://www.w3.org/2000/svg" height="50" width="50" viewBox="0 0 496 512"><!--!Font Awesome Free 6.6.0 by @fontawesome - https://fontawesome.com License - https://fontawesome.com/license/free Copyright 2024 Fonticons, Inc.--><path fill="#2094F3" d="M165.9 397.4c0 2-2.3 3.6-5.2 3.6-3.3 .3-5.6-1.3-5.6-3.6 0-2 2.3-3.6 5.2-3.6 3-.3 5.6 1.3 5.6 3.6zm-31.1-4.5c-.7 2 1.3 4.3 4.3 4.9 2.6 1 5.6 0 6.2-2s-1.3-4.3-4.3-5.2c-2.6-.7-5.5 .3-6.2 2.3zm44.2-1.7c-2.9 .7-4.9 2.6-4.6 4.9 .3 2 2.9 3.3 5.9 2.6 2.9-.7 4.9-2.6 4.6-4.6-.3-1.9-3-3.2-5.9-2.9zM244.8 8C106.1 8 0 113.3 0 252c0 110.9 69.8 205.8 169.5 239.2 12.8 2.3 17.3-5.6 17.3-12.1 0-6.2-.3-40.4-.3-61.4 0 0-70 15-84.7-29.8 0 0-11.4-29.1-27.8-36.6 0 0-22.9-15.7 1.6-15.4 0 0 24.9 2 38.6 25.8 21.9 38.6 58.6 27.5 72.9 20.9 2.3-16 8.8-27.1 16-33.7-55.9-6.2-112.3-14.3-112.3-110.5 0-27.5 7.6-41.3 23.6-58.9-2.6-6.5-11.1-33.3 2.6-67.9 20.9-6.5 69 27 69 27 20-5.6 41.5-8.5 62.8-8.5s42.8 2.9 62.8 8.5c0 0 48.1-33.6 69-27 13.7 34.7 5.2 61.4 2.6 67.9 16 17.7 25.8 31.5 25.8 58.9 0 96.5-58.9 104.2-114.8 110.5 9.2 7.9 17 22.9 17 46.4 0 33.7-.3 75.4-.3 83.6 0 6.5 4.6 14.4 17.3 12.1C428.2 457.8 496 362.9 496 252 496 113.3 383.5 8 244.8 8zM97.2 352.9c-1.3 1-1 3.3 .7 5.2 1.6 1.6 3.9 2.3 5.2 1 1.3-1 1-3.3-.7-5.2-1.6-1.6-3.9-2.3-5.2-1zm-10.8-8.1c-.7 1.3 .3 2.9 2.3 3.9 1.6 1 3.6 .7 4.3-.7 .7-1.3-.3-2.9-2.3-3.9-2-.6-3.6-.3-4.3 .7zm32.4 35.6c-1.6 1.3-1 4.3 1.3 6.2 2.3 2.3 5.2 2.6 6.5 1 1.3-1.3 .7-4.3-1.3-6.2-2.2-2.3-5.2-2.6-6.5-1zm-11.4-14.7c-1.6 1-1.6 3.6 0 5.9 1.6 2.3 4.3 3.3 5.6 2.3 1.6-1.3 1.6-3.9 0-6.2-1.4-2.3-4-3.3-5.6-2z"/></svg>
# <a href="https://github.com/AmbiqAI/heartkit/blob/main/docs/guides/train-arrhythmia-model.ipynb" class="md-content__button md-icon" style="color: #2094F3;">
#     GitHub source
# </a>
#
# </div>

# %% [markdown]
# # Train ECG Arrhythmia Classifier
#
# __Date created:__ 2024/07/17
#
# __Last Modified:__ 2024/07/17
#
# __Description:__ Train, evaluate, and export 4-stage ECG arrhythmia classifier
#
# ## Overview

# %% [markdown]
# In this guide, we will train an ECG-based arrhythmia classifier that uses an EfficientNetV2 inspired model. The classifier is trained on raw ECG data and is able to discern normal sinus rhythm (NSR), sinus bradycardia (SBRAD), atrial fibrillation (AFIB), and general supraventricular tachycardia (GSVT).
#
# __Input__
#
# - **Sensor**: ECG
# - **Location**: Wrist
# - **Sampling Rate**: 100 Hz
# - **Frame Size**: 5 seconds
#
# __Class Mapping__
#
# Identify rhythm into one of four categories: SR, SBRAD, AFIB, GSVT.
#
# | Base Class     | Target Class | Label                     |
# | -------------- | ------------ | ------------------------- |
# | 0-SR           | 0            | Sinus Rhythm (SR)         |
# | 1-SBRAD        | 1            | Sinus Bradycardia (SBRAD) |
# | 7-AFIB, 8-AFL  | 2            | AFIB/AFL (AFIB) |
# | 2-STACH, 5-SVT | 3            | General supraventricular tachycardia (GSVT) |
#
# __Datasets__
#
# - **[LSAD](https://ambiqai.github.io/heartkit/datasets/lsad/)**: The Large Scale Rhythm Database (LSAD) is a large publicly available electrocardiography dataset. It contains 10 second, 12-lead ECGs of 45,152 patients with a 500 Hz sampling rate. The ECGs are sampled at 500 Hz and are annotated by up to two cardiologists.

# %% [markdown]
# ## Setup

# %%
! pip install protobuf==3.20 wandb==0.16.6
! pip install heartkit neuralspot_edge
# Out:
# Requirement already satisfied: protobuf==3.20 in /usr/local/lib/python3.12/dist-packages (3.20.0)
# Requirement already satisfied: wandb==0.16.6 in /usr/local/lib/python3.12/dist-packages (0.16.6)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.6) (8.3.0)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.6) (3.1.45)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.6) (2.32.4)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.6) (5.9.5)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.6) (2.42.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.6) (0.4.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.6) (6.0.3)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.6) (1.3.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.6) (75.2.0)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from wandb==0.16.6) (1.4.4)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from docker-pycreds>=0.4.0->wandb==0.16.6) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from GitPython!=3.1.29,>=1.0.0->wandb==0.16.6) (4.0.12)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.16.6) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.16.6) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.16.6) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb==0.16.6) (2025.10.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb==0.16.6) (5.0.2)
# Requirement already satisfied: heartkit in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: neuralspot_edge in /usr/local/lib/python3.12/dist-packages (0.2.2)
# Requirement already satisfied: argdantic<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from argdantic[all]<2.0.0,>=1.0.0->heartkit) (1.3.3)
# Requirement already satisfied: boto3<2.0.0,>=1.34.36 in /usr/local/lib/python3.12/dist-packages (from heartkit) (1.40.63)
# Requirement already satisfied: fastparquet<2024.0.0,>=2023.10.1 in /usr/local/lib/python3.12/dist-packages (from heartkit) (2023.10.1)
# Requirement already satisfied: matplotlib<4.0.0,>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from heartkit) (3.10.0)
# Requirement already satisfied: numpy<2.0.0,>=1.26.4 in /usr/local/lib/python3.12/dist-packages (from heartkit) (1.26.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.13 in /usr/local/lib/python3.12/dist-packages (from heartkit) (3.11.4)
# Requirement already satisfied: physiokit<0.9.0,>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from heartkit) (0.8.1)
# Requirement already satisfied: plotly<6.0.0,>=5.18.0 in /usr/local/lib/python3.12/dist-packages (from heartkit) (5.24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from heartkit) (2.11.10)
# Requirement already satisfied: pyserial<4.0,>=3.5 in /usr/local/lib/python3.12/dist-packages (from heartkit) (3.5)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from heartkit) (2.32.4)
# Requirement already satisfied: rich<14.0.0,>=13.7.0 in /usr/local/lib/python3.12/dist-packages (from heartkit) (13.9.4)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from heartkit) (1.6.1)
# Requirement already satisfied: scipy<2.0.0,>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from heartkit) (1.16.3)
# Requirement already satisfied: seaborn<0.14.0,>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from heartkit) (0.13.2)
# Requirement already satisfied: tensorflow<3.0.0,>=2.17.0 in /usr/local/lib/python3.12/dist-packages (from heartkit) (2.19.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.12/dist-packages (from heartkit) (4.67.1)
# Requirement already satisfied: wandb<0.17.0,>=0.16.3 in /usr/local/lib/python3.12/dist-packages (from heartkit) (0.16.6)
# Requirement already satisfied: wfdb<5.0.0,>=4.1.2 in /usr/local/lib/python3.12/dist-packages (from heartkit) (4.3.0)
# Requirement already satisfied: h5py<4.0.0,>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from neuralspot_edge) (3.15.1)
# Requirement already satisfied: keras<4.0.0,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from neuralspot_edge) (3.10.0)
# Requirement already satisfied: pandas<3.0.0,>=2.2.2 in /usr/local/lib/python3.12/dist-packages (from neuralspot_edge) (2.3.3)
# Requirement already satisfied: pydantic-settings<3,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from argdantic<2.0.0,>=1.0.0->argdantic[all]<2.0.0,>=1.0.0->heartkit) (2.11.0)
# Requirement already satisfied: python-dotenv<2.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from argdantic[all]<2.0.0,>=1.0.0->heartkit) (1.2.1)
# Requirement already satisfied: toml<1.0,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from argdantic[all]<2.0.0,>=1.0.0->heartkit) (0.10.2)
# Requirement already satisfied: tomli<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from argdantic[all]<2.0.0,>=1.0.0->heartkit) (2.3.0)
# Requirement already satisfied: pyyaml<7.0,>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from argdantic[all]<2.0.0,>=1.0.0->heartkit) (6.0.3)
# Requirement already satisfied: tomli-w<2.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from argdantic[all]<2.0.0,>=1.0.0->heartkit) (1.2.0)
# Requirement already satisfied: botocore<1.41.0,>=1.40.63 in /usr/local/lib/python3.12/dist-packages (from boto3<2.0.0,>=1.34.36->heartkit) (1.40.63)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from boto3<2.0.0,>=1.34.36->heartkit) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from boto3<2.0.0,>=1.34.36->heartkit) (0.14.0)
# Requirement already satisfied: cramjam>=2.3 in /usr/local/lib/python3.12/dist-packages (from fastparquet<2024.0.0,>=2023.10.1->heartkit) (2.11.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from fastparquet<2024.0.0,>=2023.10.1->heartkit) (2025.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from fastparquet<2024.0.0,>=2023.10.1->heartkit) (25.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras<4.0.0,>=3.0.4->neuralspot_edge) (1.4.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras<4.0.0,>=3.0.4->neuralspot_edge) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras<4.0.0,>=3.0.4->neuralspot_edge) (0.17.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras<4.0.0,>=3.0.4->neuralspot_edge) (0.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.9.0->heartkit) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.9.0->heartkit) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.9.0->heartkit) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.9.0->heartkit) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.9.0->heartkit) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.9.0->heartkit) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.9.0->heartkit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.2->neuralspot_edge) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.2->neuralspot_edge) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly<6.0.0,>=5.18.0->heartkit) (8.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.5.3->heartkit) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.5.3->heartkit) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.5.3->heartkit) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.5.3->heartkit) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.31.0->heartkit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.31.0->heartkit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.31.0->heartkit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.31.0->heartkit) (2025.10.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich<14.0.0,>=13.7.0->heartkit) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich<14.0.0,>=13.7.0->heartkit) (2.19.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2.0.0,>=1.4.0->heartkit) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2.0.0,>=1.4.0->heartkit) (3.6.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<3.0.0,>=2.17.0->heartkit) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow<3.0.0,>=2.17.0->heartkit) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<3.0.0,>=2.17.0->heartkit) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<3.0.0,>=2.17.0->heartkit) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<3.0.0,>=2.17.0->heartkit) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow<3.0.0,>=2.17.0->heartkit) (3.4.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow<3.0.0,>=2.17.0->heartkit)
#   Using cached protobuf-5.29.5-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow<3.0.0,>=2.17.0->heartkit) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<3.0.0,>=2.17.0->heartkit) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<3.0.0,>=2.17.0->heartkit) (3.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<3.0.0,>=2.17.0->heartkit) (2.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow<3.0.0,>=2.17.0->heartkit) (1.76.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<3.0.0,>=2.17.0->heartkit) (2.19.0)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.12/dist-packages (from wandb<0.17.0,>=0.16.3->heartkit) (8.3.0)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb<0.17.0,>=0.16.3->heartkit) (3.1.45)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb<0.17.0,>=0.16.3->heartkit) (5.9.5)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb<0.17.0,>=0.16.3->heartkit) (2.42.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from wandb<0.17.0,>=0.16.3->heartkit) (0.4.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.12/dist-packages (from wandb<0.17.0,>=0.16.3->heartkit) (1.3.7)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from wandb<0.17.0,>=0.16.3->heartkit) (1.4.4)
#   Using cached protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: aiohttp>=3.10.11 in /usr/local/lib/python3.12/dist-packages (from wfdb<5.0.0,>=4.1.2->heartkit) (3.13.1)
# Requirement already satisfied: soundfile>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from wfdb<5.0.0,>=4.1.2->heartkit) (0.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb<5.0.0,>=4.1.2->heartkit) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb<5.0.0,>=4.1.2->heartkit) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb<5.0.0,>=4.1.2->heartkit) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb<5.0.0,>=4.1.2->heartkit) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb<5.0.0,>=4.1.2->heartkit) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb<5.0.0,>=4.1.2->heartkit) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.11->wfdb<5.0.0,>=4.1.2->heartkit) (1.22.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow<3.0.0,>=2.17.0->heartkit) (0.45.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from GitPython!=3.1.29,>=1.0.0->wandb<0.17.0,>=0.16.3->heartkit) (4.0.12)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.7.0->heartkit) (0.1.2)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.10.0->wfdb<5.0.0,>=4.1.2->heartkit) (2.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow<3.0.0,>=2.17.0->heartkit) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow<3.0.0,>=2.17.0->heartkit) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow<3.0.0,>=2.17.0->heartkit) (3.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.10.0->wfdb<5.0.0,>=4.1.2->heartkit) (2.23)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb<0.17.0,>=0.16.3->heartkit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow<3.0.0,>=2.17.0->heartkit) (3.0.3)
# Using cached protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.0
#     Uninstalling protobuf-3.20.0:
#       Successfully uninstalled protobuf-3.20.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.8 which is incompatible.
# opentelemetry-proto 1.37.0 requires protobuf<7.0,>=5.0, but you have protobuf 4.25.8 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.8 which is incompatible.
# Successfully installed protobuf-4.25.8

# %%
import os
import numpy as np
np.float_ = np.float64
np.complex_ = np.complex128
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
import IPython
import contextlib
from pathlib import Path
import tempfile
import keras
import heartkit as hk
import neuralspot_edge as nse

# %%
# Be sure to set the dataset path to the correct location
datasets_dir = Path(os.getenv("HK_DATASET_PATH", "./datasets"))
import neuralspot_edge as nse
import heartkit.utils as wonka
plot_theme = wonka.dark_theme
nse.utils.silence_tensorflow()
wonka.setup_plotting(plot_theme)
logger = nse.utils.setup_logger(__name__)

# %% [markdown]
# ## Configure datasets
#
# We are going to train our model using the [Large scale Arrhythmia dataset](https://ambiqai.github.io/heartkit/datasets/lsad/). This dataset uses the slug __lsad__ within HeartKit. We will download the dataset if it is not already available.

# %%
datasets = [
    hk.NamedParams(
        name="lsad",
        params=dict(
            path=datasets_dir / "lsad",
        ),
    )
]

# %% [markdown]
# ## Target classes
#
# For this task, we are going to classify ECG signals into one of four classes:
#
# * Sinus Rhytm: Normal ECG signal (SR)
# * Sinus Bradycardia: Slow heart rate (SB)
# * Atrial Flutter/Fibrillation: Irregular heart rate (AFIB)
# * General Supra-Ventricular Tachycardia: Fast heart rate (GSVT)
#
# HeartKit already provides a number of heart rhythms. We will provide a class mapping for the four classes we are interested in. We will also provide class names for display purposes.

# %%
class_map = {
    hk.tasks.HKRhythm.sr: 0,
    hk.tasks.HKRhythm.sbrad: 1,
    hk.tasks.HKRhythm.afib: 2,
    hk.tasks.HKRhythm.aflut: 2,
    hk.tasks.HKRhythm.stach: 3,
    hk.tasks.HKRhythm.svt: 3,
}

class_names = ["SR", "SB", "AFIB", "GSVT"]

# %% [markdown]
# ## Preprocess pipeline
#
# We will preprocess the ECG signals by applying the following steps:
# * Apply Z-score normalization w/ epsilon to avoid division by zero
#
# The task accepts a list of preprocessing functions that will be applied to the input data.

# %%
preprocesses = [hk.NamedParams(name="layer_norm", params=dict(epsilon=0.01, name="znorm"))]

# %% [markdown]
# ## Define EfficientNetV2 model architecture
#
# For this task, we are going to leverage a customized __EfficientNetV2__ model architecture that is smaller and can handle 1D signals. The model consists of 6 MBConv style blocks with a depth of 2. Each block leverages squeeze-and-excitation mechanism w/ ratio of 4 to improve the model's performance.

# %%
architecture = hk.NamedParams(
    name="efficientnetv2",
    params=dict(
        input_filters=24,
        input_kernel_size=(1, 9),
        input_strides=(1, 2),
        blocks=[
            dict(filters=24, depth=1, kernel_size=(1, 9), strides=(1, 2), ex_ratio=1, se_ratio=4),
            dict(filters=32, depth=1, kernel_size=(1, 9), strides=(1, 2), ex_ratio=1, se_ratio=4),
            dict(filters=48, depth=1, kernel_size=(1, 9), strides=(1, 2), ex_ratio=1, se_ratio=4),
            dict(filters=64, depth=1, kernel_size=(1, 9), strides=(1, 2), ex_ratio=1, se_ratio=4),
            dict(filters=80, depth=1, kernel_size=(1, 9), strides=(1, 2), ex_ratio=1, se_ratio=4),
            dict(filters=96, depth=1, kernel_size=(1, 9), strides=(1, 2), ex_ratio=1, se_ratio=4),
        ],
        output_filters=0,
        include_top=True,
        use_logits=True,
    ),
)

# %% [markdown]
# ## Task configuration
#
# Here we provide the complete configuration for the task. This includes the dataset configuration, preprocessing pipeline, model architecture, and training parameters.

# %%
params = hk.HKTaskParams(
    # Common arguments
    name="hk-4-stage-rhythm",
    job_dir=Path("/home/user/ecg_classifier_output"), # Modified to save to a specific directory
    # Dataset arguments
    datasets=datasets,
    # Signal arguments
    sampling_rate=100,
    frame_size=800,
    # Dataloader arguments
    samples_per_patient=5,
    val_samples_per_patient=5,
    test_samples_per_patient=5,
    # Preprocessing/Augmentation arguments
    preprocesses=preprocesses,
    # Class arguments
    num_classes=len(class_names),
    class_map=class_map,
    class_names=class_names,
    # Split arguments
    val_patients=0.2,
    val_size=20000,
    test_size=20000,
    val_file="val.tfds",
    test_file="val.tfds",
    # Model arguments
    model_file="model.keras",
    architecture=architecture,
    # Training parameters
    lr_rate=1e-3,
    lr_cycles=1,
    batch_size=256,
    buffer_size=25000,
    epochs=100,
    steps_per_epoch=50,
    val_metric="loss",
    class_weights="balanced",
    # Evaluation arguments
    threshold=0.5,
    test_metric_threshold=0.98,
    # Export parameters
    tflm_var_name="ecg_rhythm_flatbuffer",
    tflm_file="ecg_rhythm_flatbuffer.h",
    # Demo params
    backend="pc",
    demo_size=800,
    display_report=False,
    # Extra arguments
    verbose=1,
    seed=42,
)

# %%
print(params.job_dir)
# Out:
# /home/user/ecg_classifier_output

# %% [markdown]
# ## Load rhythm task
#
# HeartKit provides a __TaskFactory__ that includes a number ready-to-use tasks. Each task provides methods for training, evaluating, exporting, and demoing. We will grab the __rhythm__ task and configure it for our use case.

# %%
task = hk.TaskFactory.get("rhythm")

# %% [markdown]
# ## Download datasets
#
# We will download the datasets needed for the task.

# %%
task.download(params=params)

# %% [markdown]
# ## Visualize the model
#
# Lets quickly instantiate and visualize the first few layers of the model.

# %%
import neuralspot_edge as nse
x=keras.Input(shape=(params.frame_size, 1), name="inputs")
model = nse.models.efficientnet.EfficientNetV2Model()
model.model_from_params(x,architecture.params)
# Out:
# <Functional name=functional, built=True>

# %% [markdown]
# ## Train the model
#
# Now let's train the model using the LSAD dataset. We will train the model for 100 epochs.

# %%
task.train(params)
# Out:
# Sorting lsad labels:   0%|          | 0/36120 [00:00<?, ?it/s]
# Sorting lsad labels:   0%|          | 0/36120 [00:00<?, ?it/s]
# INFO     Validation steps per epoch: 78                                                             ]8;id=977579;file:///usr/local/lib/python3.12/dist-packages/heartkit/tasks/rhythm/datasets.py\datasets.py]8;;\:]8;id=747916;file:///usr/local/lib/python3.12/dist-packages/heartkit/tasks/rhythm/datasets.py#105\105]8;;\
# INFO     Saving validation dataset to /home/user/ecg_classifier_output/val.tfds                         ]8;id=726134;file:///usr/local/lib/python3.12/dist-packages/heartkit/tasks/rhythm/train.py\train.py]8;;\:]8;id=806366;file:///usr/local/lib/python3.12/dist-packages/heartkit/tasks/rhythm/train.py#57\57]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training:  84%|████████▍  84/100 ETA: 09:26s,  35.42s/epochs

# %% [markdown]
# ## Model evaluation
#
# Now that we have trained the model, we will evaluate the model on the test dataset. Similar to training, we will provide the same task parameters.

# %%
task.evaluate(params)

# %% [markdown]
# ## Confusion matrix
#
# Let's visualize the confusion matrix to understand the model's performance on each class.

# %%
IPython.display.Image(filename=params.job_dir / "confusion_matrix_test.png", width=500)

# %% [markdown]
# ## Export model to TF Lite / TFLM
#
# Once we have trained and evaluated the model, we need to export the model into a format that can be used for inference on the edge. Currently, we export the model to TensorFlow Lite flatbuffer format. This will also generate a C header file that can be used with TensorFlow Lite for Microcontrollers (TFLM).
#
#
# ### Apply post-training quantization (PTQ)
#
# For running on bare metal, we will perform post-training quantization to convert the model to an 8-bit integer model. The weights and activations will be quantized to 8-bits and biases will be quantized to 32-bits. This will reduce the model size and improve the inference speed.

# %%
quantization = hk.QuantizationParams(
    enabled=True,
    format="INT8",
    io_type="int8",
    conversion="KERAS",
)
params.quantization = quantization

# %%
# TF dumps a lot of info to stdout, so we redirect it to /dev/null
with open(os.devnull, "w") as devnull:
    with contextlib.redirect_stdout(devnull), contextlib.redirect_stderr(devnull):
        task.export(params=params)

# %% [markdown]
# ## Run inference demo
#
# We will run a demo on the PC to verify that the model is working as expected. The demo will load the model and run inferences across a randomly selected ECG signal. The demo will also provide the model's prediction and the corresponding class name.

# %%
task.demo(params=params)
